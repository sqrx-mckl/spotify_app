# %%
with pd.option_context('display.max_rows', None):
    pprint(df_toptracks.iloc[0,:])
# Out:
# available_markets                            [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# disc_number                                                                                  1
# duration_ms                                                                             222166
# explicit                                                                                 False
# href                                         https://api.spotify.com/v1/tracks/5qsFOopazL2H...
# id                                                                      5qsFOopazL2HXDtpotj0mz
# is_local                                                                                 False
# name                                                                              hypnic jerks
# popularity                                                                                  38
# preview_url                                  https://p.scdn.co/mp3-preview/6d6466538bfe65f1...
# track_number                                                                                 8
# type                                                                                     track
# uri                                                       spotify:track:5qsFOopazL2HXDtpotj0mz
# album.album_type                                                                         ALBUM
# album.artists.0.external_urls.spotify        https://open.spotify.com/artist/25CgccXK9hJBTu...
# album.artists.0.href                         https://api.spotify.com/v1/artists/25CgccXK9hJ...
# album.artists.0.id                                                      25CgccXK9hJBTuaMF44zeR
# album.artists.0.name                                                 The Spirit of the Beehive
# album.artists.0.type                                                                    artist
# album.artists.0.uri                                      spotify:artist:25CgccXK9hJBTuaMF44zeR
# album.available_markets                      [AD, AE, AR, AT, AU, BE, BG, BH, BO, BR, CA, C...
# album.external_urls.spotify                  https://open.spotify.com/album/3M1hjHgDdFdhZKQ...
# album.href                                   https://api.spotify.com/v1/albums/3M1hjHgDdFdh...
# album.id                                                                3M1hjHgDdFdhZKQRAccl8n
# album.images.0.height                                                                      640
# album.images.0.url                           https://i.scdn.co/image/ab67616d0000b273c8379f...
# album.images.0.width                                                                       640
# album.images.1.height                                                                      300
# album.images.1.url                           https://i.scdn.co/image/ab67616d00001e02c8379f...
# album.images.1.width                                                                       300
# album.images.2.height                                                                       64
# album.images.2.url                           https://i.scdn.co/image/ab67616d00004851c8379f...
# album.images.2.width                                                                        64
# album.name                                                                        Hypnic Jerks
# album.release_date                                                                  2018-09-14
# album.release_date_precision                                                               day
# album.total_tracks                                                                          10
# album.type                                                                               album
# album.uri                                                 spotify:album:3M1hjHgDdFdhZKQRAccl8n
# artists.0.external_urls.spotify              https://open.spotify.com/artist/25CgccXK9hJBTu...
# artists.0.href                               https://api.spotify.com/v1/artists/25CgccXK9hJ...
# artists.0.id                                                            25CgccXK9hJBTuaMF44zeR
# artists.0.name                                                       The Spirit of the Beehive
# artists.0.type                                                                          artist
# artists.0.uri                                            spotify:artist:25CgccXK9hJBTuaMF44zeR
# external_ids.isrc                                                                 QMZPB1800308
# external_urls.spotify                        https://open.spotify.com/track/5qsFOopazL2HXDt...
# album.artists.1.external_urls.spotify                                                      NaN
# album.artists.1.href                                                                       NaN
# album.artists.1.id                                                                         NaN
# album.artists.1.name                                                                       NaN
# album.artists.1.type                                                                       NaN
# album.artists.1.uri                                                                        NaN
# artists.1.external_urls.spotify                                                            NaN
# artists.1.href                                                                             NaN
# artists.1.id                                                                               NaN
# artists.1.name                                                                             NaN
# artists.1.type                                                                             NaN
# artists.1.uri                                                                              NaN
# index                                                                                        0
# artists.0.id.enrich.index                                                                    0
# artists.0.id.enrich.genres                   [american shoegaze, experimental pop, garage p...
# artists.0.id.enrich.href                     https://api.spotify.com/v1/artists/25CgccXK9hJ...
# artists.0.id.enrich.id                                                  25CgccXK9hJBTuaMF44zeR
# artists.0.id.enrich.name                                             The Spirit of the Beehive
# artists.0.id.enrich.popularity                                                              44
# artists.0.id.enrich.type                                                                artist
# artists.0.id.enrich.uri                                  spotify:artist:25CgccXK9hJBTuaMF44zeR
# artists.0.id.enrich.external_urls.spotify    https://open.spotify.com/artist/25CgccXK9hJBTu...
# artists.0.id.enrich.followers.href                                                        None
# artists.0.id.enrich.followers.total                                                      15227
# artists.0.id.enrich.images.0.height                                                        640
# artists.0.id.enrich.images.0.url             https://i.scdn.co/image/c2fe9fa483822d914e6f1b...
# artists.0.id.enrich.images.0.width                                                         640
# artists.0.id.enrich.images.1.height                                                        320
# artists.0.id.enrich.images.1.url             https://i.scdn.co/image/a704caa01ba56c314c56d0...
# artists.0.id.enrich.images.1.width                                                         320
# artists.0.id.enrich.images.2.height                                                        160
# artists.0.id.enrich.images.2.url             https://i.scdn.co/image/2fb2e5e3ea8198a8a54838...
# artists.0.id.enrich.images.2.width                                                         160
# artists.0.id.enrich.images.3.height                                                        NaN
# artists.0.id.enrich.images.3.url                                                           NaN
# artists.0.id.enrich.images.3.width                                                         NaN
# window                                                                                       0
# level_1                                                                                      0
# id.enrich.index                                                                              0
# id.enrich.danceability                                                                   0.557
# id.enrich.energy                                                                         0.673
# id.enrich.key                                                                                7
# id.enrich.loudness                                                                      -8.312
# id.enrich.mode                                                                               1
# id.enrich.speechiness                                                                   0.0294
# id.enrich.acousticness                                                                5.88e-05
# id.enrich.instrumentalness                                                               0.756
# id.enrich.liveness                                                                       0.603
# id.enrich.valence                                                                        0.582
# id.enrich.tempo                                                                        149.033
# id.enrich.type                                                                  audio_features
# id.enrich.id                                                            5qsFOopazL2HXDtpotj0mz
# id.enrich.uri                                             spotify:track:5qsFOopazL2HXDtpotj0mz
# id.enrich.track_href                         https://api.spotify.com/v1/tracks/5qsFOopazL2H...
# id.enrich.analysis_url                       https://api.spotify.com/v1/audio-analysis/5qsF...
# id.enrich.duration_ms                                                                   222166
# id.enrich.time_signature                                                                     4
# Name: 0, dtype: object

# %% [markdown]
#  Let's retrieve the most useful column for our analysis like:
#  * related to music features
#  * to classify it (name, etc...)
#  * release date (could be related to a specific era)

# %%
df = df_toptracks[[
    'id',
    'name',
    'artists.0.id.enrich.name',
    'album.release_date',
    'artists.0.id.enrich.genres',
    'popularity',
    'duration_ms',
    'artists.0.id.enrich.popularity',
    'artists.0.id.enrich.followers.total',
    'id.enrich.danceability',
    'id.enrich.energy',
    'id.enrich.key',
    'id.enrich.loudness',
    'id.enrich.mode',
    'id.enrich.speechiness',
    'id.enrich.acousticness',
    'id.enrich.instrumentalness',
    'id.enrich.liveness',
    'id.enrich.valence',
    'id.enrich.tempo',
    'id.enrich.time_signature',
]]

df_plot:pd.DataFrame = df.drop([
    'id',
    'name',
    'artists.0.id.enrich.name',
    'album.release_date',
    'artists.0.id.enrich.genres'
], axis=1)

sns.set_context('notebook')
#%matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12, 9) # (w, h)

df_plot.hist(sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe70e9910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe6ab6a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe6a34d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe69eaf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe699fa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe695dc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe69167d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe68c8e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe68d39d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe6894210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe687fd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe68378d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe67ebf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe67ad610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe6762c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fe6723e90>]],
#       dtype=object)

# %%
# (apply sklearn.preprocessing.MultiLabelBinarizer on "genre")
#//TODO request the audio features
